# %%
'''
Details for LRW dataset:
- 500 words (check lrw_list.txt)
- 800-1000 train videos per word
- 50 test and 50 validation videos per word
- Split into train, test, and validation sets
- All videos are 29 frames long (1.16 seconds)
- Word occurs roughly in the middle

TODO: (update as completed)
- Switch labels to numeric or one-hot (currently strings)
- Experiement with transformations of the data
- Experiement with trimming the video to cut out unneeded words, and reduce number of frames
'''

import torch
import torch.nn.functional as F
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np
import os
import random
import time
import pytorchvideo #look up how to use this
import cv2
import math
import torch
from torch import nn, einsum
import torch.nn.functional as F
from einops import rearrange, repeat
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import torch.optim as optim
from IPython.display import Video, HTML
from playsound import playsound
from tqdm import tqdm
from timesformer_pytorch.rotary import apply_rot_emb, AxialRotaryEmbedding, RotaryEmbedding

torch.cuda.empty_cache()

NUM_FRAMES = 29 # Make sure to set all new videos to this length
FPS = 25
TIME = 1.16
NUM_CLASSES = 50

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
# device = 'cpu'
random.seed(time.time())
RANDOM_SEED = random.randint(0, 2**32 - 1)

# %%
class LipReadDataset(Dataset):
    def __init__(self, root_dir, split, device, transform=None):
        """
        Initialize the dataset.
        Args:
            video_paths (list): List of file paths to video files.
            labels (list): List of corresponding labels.
            transform (callable, optional): Optional data transformations (e.g., resizing, normalization).
        """
        # self.word_folders = 
        # print(self.word_folders)
        # self.frames = []
        self.frame_titles = []
        self.labels = []
        self.device = device
        self.word_dict = {}
        self.num_classes = 0
        self.transform = transform
        # self.split = split
        # self.prefix = root_dir
        random.seed(RANDOM_SEED) #ensure words are the same bewtween datasets
        word_folders = os.listdir(root_dir)
        random.shuffle(word_folders)

        for word_folder in word_folders:
            set_path = os.path.join(root_dir, word_folder, split)
            self.word_dict[word_folder] = self.num_classes
            self.num_classes += 1
            # want to test with 10 words first
            if self.num_classes == NUM_CLASSES:
                break
            num_videos = 0
            video_files = os.listdir(set_path)
            random.seed(time.time()) #shuffle videos randomly
            random.shuffle(video_files)
            for video_file in video_files:
                video_path = os.path.join(set_path, video_file)
                if video_path.endswith('.txt'): # want to use later
                    continue
                num_videos += 1
                if num_videos == 100:
                    break
                # curr_frames = self.extract_frames(video_path)
                self.labels.append(word_folder)
                # self.frames.append(curr_frames)
                self.frame_titles.append(video_path)
                print(f"added {video_path} to {split} set")
        self.transform = transform
        assert self.num_classes == len(self.word_dict)

    def __len__(self):
        """Return the total number of samples in the dataset."""
        return len(self.labels)

    def __getitem__(self, idx):
        """
        Get a specific sample from the dataset.
        Args:
            idx (int): Index of the sample.
        Returns:
            video (tensor): Video frames (e.g., as a sequence of images).
            label (int): Corresponding label.
        """
        # extract video
        # Apply any necessary transformations (e.g., resizing, normalization)
        # if self.transform:
        #     video = self.transform(video)
        # Convert the label to a one-hot encoded tensor
        return self.extract_frames(self.frame_titles[idx]), self.one_hot_encode(self.labels[idx])
    
    def one_hot_encode(self, labels):
        # Convert labels to one-hot encoding
        one_hot = torch.zeros(NUM_CLASSES, device=self.device)
        one_hot[self.word_dict[labels]] = 1
        return one_hot
        

    def extract_frames(self, video_path, duration=1.16, target_resolution = (40,65)):
        # Read the video
        cap = cv2.VideoCapture(video_path)
        # EXPERIEMENT WITH THIS
        # duration_frames = int(duration * FPS)
        # end_frame = NUM_FRAMES -  9 # skip the last 9 frames
        # start_frame = end_frame - duration_frames # get middle frames
        frames = []
        # cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)

        while cap.isOpened():
            ret, frame = cap.read()
            if ret:
                # if cap.get(cv2.CAP_PROP_POS_FRAMES) == end_frame:
                #     break
                frame_cropped = frame[120:216, 80:176] # Crop the frame
                # frame_resized = cv2.resize(frame_cropped, target_resolution)
                if self.transform:
                    frame_tensor = self.transform(frame_cropped)
                # frame_gray = cv2.cvtColor(frame_resized, cv2.COLOR_BGR2GRAY)
                # frame_tensor = torch.from_numpy(frame_gray).to(self.device)
                frame_tensor.to(self.device) #double check
                frames.append(frame_tensor)
            else:
                break
        cap.release()
        video_tensor = torch.stack(frames, dim=0).to(self.device)
        # video_tensor = video_tensor.permute(1, 0, 2, 3)  # assuming the original channel dimension is at index 1
        return video_tensor

# %%
transform = transforms.Compose([
    transforms.ToTensor(),  # Convert frames to PyTorch tensors
    # transforms.Resize((40, 65)),  # Resize frames to smaller resolution
    transforms.Grayscale(),
    transforms.Normalize(mean=[0.5], std=[0.5]),
])


root_dir = 'lipread_mp4'

print(device)
trainset = LipReadDataset(root_dir, split='train', device=device, transform=transform)
print("finished trainset")
testset = LipReadDataset(root_dir, split='test',device=device, transform=transform)
print("finished testset")
valset = LipReadDataset(root_dir, split='val', device=device, transform=transform)
print("finished valset")
# Out:
# cuda:0
# added lipread_mp4\DAVID\train\DAVID_00060.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00226.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00232.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00834.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00900.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00414.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00407.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00228.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00529.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00446.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00810.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00234.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00543.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00343.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00028.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00721.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00373.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00680.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00874.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00410.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00465.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00037.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00051.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00783.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00493.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00303.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00522.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00302.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00767.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00546.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00941.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00458.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00831.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00286.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00275.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00236.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00374.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00105.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00177.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00628.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00468.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00243.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00906.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00549.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00506.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00464.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00682.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00449.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00077.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00358.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00266.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00617.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00022.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00775.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00069.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00619.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00998.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00881.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00031.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00103.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00534.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00788.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00875.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00406.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00052.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00293.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00381.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00364.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00764.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00840.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00715.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00489.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00977.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00469.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00758.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00693.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00471.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00401.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00943.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00636.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00024.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00536.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00049.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00308.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00733.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00820.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00804.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00363.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00247.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00520.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00163.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00175.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00681.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00716.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00385.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00824.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00924.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00281.mp4 to train set
# added lipread_mp4\DAVID\train\DAVID_00935.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00840.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00310.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00859.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00256.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00507.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00851.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00732.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00730.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00215.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00214.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00646.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00191.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00026.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00771.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00676.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00675.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00311.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00889.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00726.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00063.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00233.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00225.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00720.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00609.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00812.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00627.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00221.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00536.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00434.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00678.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00775.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00018.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00058.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00565.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00119.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00161.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00133.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00014.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00348.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00013.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00584.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00715.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00480.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00060.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00832.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00165.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00300.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00231.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00223.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00888.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00449.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00219.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00611.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00637.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00498.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00154.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00203.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00391.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00206.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00564.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00006.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00172.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00750.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00713.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00825.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00405.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00082.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00116.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00573.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00438.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00478.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00579.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00088.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00583.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00465.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00474.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00320.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00744.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00039.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00399.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00807.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00659.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00122.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00818.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00400.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00907.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00459.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00776.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00694.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00228.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00643.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00799.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00065.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00681.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00303.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00307.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00101.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00328.mp4 to train set
# added lipread_mp4\WINDS\train\WINDS_00901.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00290.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00441.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00873.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00007.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00457.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00696.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00060.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00415.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00310.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00615.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00547.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00357.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00261.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00275.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00016.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00303.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00535.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00889.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00930.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00209.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00055.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00910.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00514.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00942.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00183.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00634.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00577.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00398.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00355.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00879.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00324.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00017.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00470.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00538.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00137.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00243.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00309.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00620.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00623.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00658.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00718.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00689.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00795.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00793.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00389.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00738.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00066.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00919.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00217.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00584.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00232.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00010.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00382.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00130.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00648.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00884.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00337.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00537.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00852.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00714.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00545.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00642.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00381.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00280.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00210.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00705.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00941.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00757.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00322.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00796.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00484.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00870.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00916.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00955.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00452.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00756.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00021.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00117.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00151.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00497.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00122.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00878.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00349.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00607.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00499.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00773.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00325.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00227.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00949.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00041.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00332.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00428.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00596.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00810.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00591.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00456.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00476.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00414.mp4 to train set
# added lipread_mp4\WARNING\train\WARNING_00289.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00594.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00294.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00585.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00595.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00889.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00977.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00893.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00399.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00254.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00345.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00185.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00702.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00696.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00457.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00760.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00780.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00558.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00023.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00162.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00707.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00265.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00278.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00582.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00066.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00158.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00953.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00699.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00509.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00438.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00608.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00148.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00329.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_01000.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00941.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00059.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00635.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00106.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00767.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00018.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00417.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00319.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00981.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00794.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00091.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00428.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00854.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00881.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00974.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00150.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00743.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00090.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00342.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00282.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00414.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00695.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00033.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00599.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00408.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00895.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00726.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00448.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00433.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00218.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00490.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00555.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00901.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00272.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00017.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00717.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00910.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00233.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00248.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00768.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00129.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00432.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00883.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00371.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00591.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00784.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00793.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00758.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00964.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00171.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00191.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00071.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00113.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00052.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00802.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00870.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00827.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00426.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00108.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00251.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00556.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00085.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00867.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00022.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00115.mp4 to train set
# added lipread_mp4\AREAS\train\AREAS_00093.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00089.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00034.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00203.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00276.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00386.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00820.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00803.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00877.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00423.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00262.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00308.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00377.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00470.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00669.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00902.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00179.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00957.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00508.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00108.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00915.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00317.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00280.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00513.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00863.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00837.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00771.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00630.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00752.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00545.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00808.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00083.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00978.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00910.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00331.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00302.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00214.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00450.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00318.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00053.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00236.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00680.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00520.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00106.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00467.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00303.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00578.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00119.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00285.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00832.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00145.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00126.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00740.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00918.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00480.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00865.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00746.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00621.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00012.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00306.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00529.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00177.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00033.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00291.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00714.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00189.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00617.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00300.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00486.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00375.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00930.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00359.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00441.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00552.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00223.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00046.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00778.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00958.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00114.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00365.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00629.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00916.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00921.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00115.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00459.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00354.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00502.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00471.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00551.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00197.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00154.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00853.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00449.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00575.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00038.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00745.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00380.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00342.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00602.mp4 to train set
# added lipread_mp4\PARENTS\train\PARENTS_00995.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00686.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00545.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00722.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00820.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00805.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00876.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00979.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00597.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00136.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00036.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00168.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00798.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00834.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00759.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00348.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00161.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00290.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00076.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00330.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00443.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00998.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00347.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00008.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00958.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00069.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00942.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00295.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00338.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00740.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00714.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00402.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00249.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00660.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00857.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00939.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00976.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00710.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00465.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00562.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00858.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00503.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00239.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00540.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00926.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00336.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00524.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00787.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00492.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00207.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00241.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00588.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00310.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00793.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00442.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00284.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00367.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00529.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00287.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00508.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00118.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00669.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00931.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00424.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00028.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00420.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00062.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00405.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00282.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00016.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00576.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00711.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00566.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00480.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00078.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00766.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00515.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00066.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00134.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00844.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00591.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00360.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00326.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00110.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00851.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00115.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00539.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00320.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00511.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00792.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00355.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00186.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00692.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00021.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00244.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00696.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00963.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00195.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00901.mp4 to train set
# added lipread_mp4\SUNDAY\train\SUNDAY_00904.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00777.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00600.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00808.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00593.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00449.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00646.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00480.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00164.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00515.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00813.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00055.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00050.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00565.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00182.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00965.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00335.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00752.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00609.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00839.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00206.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00724.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00868.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00587.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00797.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00019.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00693.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00236.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00998.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00494.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00915.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00911.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00331.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00133.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00082.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00365.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00244.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00755.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00792.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00306.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00354.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00054.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00438.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00231.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00888.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00085.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00529.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00291.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00714.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00003.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00479.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00703.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00745.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00201.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00168.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00312.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00895.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00766.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00216.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00191.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00458.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00362.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00420.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00607.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00696.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00954.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00964.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00288.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00349.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00052.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00125.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00408.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00975.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00322.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00623.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00853.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00746.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00010.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00790.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00477.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00314.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00835.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00952.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00243.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00339.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00268.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00116.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00988.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00178.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00818.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00867.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00410.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00195.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00342.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00687.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00817.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00657.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00388.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00181.mp4 to train set
# added lipread_mp4\SITUATION\train\SITUATION_00469.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00746.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00919.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00300.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00226.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00301.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00034.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00957.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00758.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00484.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00350.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00574.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00475.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00657.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00480.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00691.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00579.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00367.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00972.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00262.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00543.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00046.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00297.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00429.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00838.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00004.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00062.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00024.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00313.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00035.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00125.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00365.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00980.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00788.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00136.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00912.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00170.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00007.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00282.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00315.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00488.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00100.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00122.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00047.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00405.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00917.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00705.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00906.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00784.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00267.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00635.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00463.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00892.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00706.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00066.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00781.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00607.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00812.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00506.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00456.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00736.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00248.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00155.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00548.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00504.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00264.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00759.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00349.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00023.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00894.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00469.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00382.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00142.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00078.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00389.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00497.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00886.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00079.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00431.mp4 to train set
# added lipread_mp4\YESTERDAY\train\YESTERDAY_00878.mp4 to train set
# ...
# added lipread_mp4\GROUND\val\GROUND_00036.mp4 to val set
# added lipread_mp4\GROUND\val\GROUND_00008.mp4 to val set
# added lipread_mp4\GROUND\val\GROUND_00011.mp4 to val set
# added lipread_mp4\GROUND\val\GROUND_00038.mp4 to val set
# added lipread_mp4\GROUND\val\GROUND_00043.mp4 to val set
# added lipread_mp4\GROUND\val\GROUND_00024.mp4 to val set
# added lipread_mp4\GROUND\val\GROUND_00004.mp4 to val set
# added lipread_mp4\GROUND\val\GROUND_00001.mp4 to val set
# added lipread_mp4\GROUND\val\GROUND_00048.mp4 to val set
# added lipread_mp4\GROUND\val\GROUND_00040.mp4 to val set
# added lipread_mp4\GROUND\val\GROUND_00028.mp4 to val set
# added lipread_mp4\GROUND\val\GROUND_00049.mp4 to val set
# added lipread_mp4\GROUND\val\GROUND_00006.mp4 to val set
# added lipread_mp4\GROUND\val\GROUND_00042.mp4 to val set
# added lipread_mp4\GROUND\val\GROUND_00012.mp4 to val set
# added lipread_mp4\GROUND\val\GROUND_00029.mp4 to val set
# added lipread_mp4\GROUND\val\GROUND_00018.mp4 to val set
# added lipread_mp4\GROUND\val\GROUND_00027.mp4 to val set
# added lipread_mp4\GROUND\val\GROUND_00002.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00009.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00019.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00010.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00012.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00048.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00005.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00002.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00027.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00039.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00045.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00043.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00013.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00015.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00041.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00040.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00025.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00017.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00008.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00035.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00047.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00038.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00001.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00029.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00014.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00036.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00028.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00006.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00011.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00033.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00024.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00016.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00022.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00050.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00044.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00032.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00037.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00031.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00042.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00023.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00026.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00034.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00020.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00030.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00003.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00004.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00049.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00018.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00021.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00007.mp4 to val set
# added lipread_mp4\EXPECTED\val\EXPECTED_00046.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00039.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00035.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00037.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00045.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00021.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00025.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00015.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00042.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00018.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00047.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00028.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00019.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00023.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00034.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00017.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00009.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00006.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00001.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00044.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00008.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00031.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00024.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00026.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00036.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00030.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00002.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00038.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00010.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00007.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00011.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00050.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00016.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00029.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00032.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00033.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00014.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00004.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00012.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00020.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00048.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00040.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00027.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00041.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00003.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00046.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00013.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00049.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00005.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00043.mp4 to val set
# added lipread_mp4\DOING\val\DOING_00022.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00002.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00023.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00015.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00016.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00010.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00008.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00036.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00026.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00011.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00009.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00007.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00042.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00012.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00050.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00014.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00046.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00039.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00034.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00028.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00040.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00045.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00001.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00027.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00030.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00033.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00020.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00038.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00017.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00003.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00032.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00022.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00044.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00047.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00035.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00018.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00037.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00031.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00005.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00021.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00013.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00049.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00043.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00006.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00024.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00041.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00025.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00048.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00019.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00004.mp4 to val set
# added lipread_mp4\MINUTES\val\MINUTES_00029.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00005.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00042.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00046.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00012.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00031.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00015.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00041.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00006.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00045.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00027.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00032.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00026.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00019.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00034.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00010.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00023.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00048.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00024.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00020.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00043.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00016.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00013.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00030.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00038.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00007.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00036.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00004.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00029.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00003.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00040.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00049.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00050.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00022.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00001.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00028.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00044.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00018.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00035.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00017.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00047.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00021.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00002.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00037.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00025.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00011.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00008.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00039.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00009.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00033.mp4 to val set
# added lipread_mp4\SPENDING\val\SPENDING_00014.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00032.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00004.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00011.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00036.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00045.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00022.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00014.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00039.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00047.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00029.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00037.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00024.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00049.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00005.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00018.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00035.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00021.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00017.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00013.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00023.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00002.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00042.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00026.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00015.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00034.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00030.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00031.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00040.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00025.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00027.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00028.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00012.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00038.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00043.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00048.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00003.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00033.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00016.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00010.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00041.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00008.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00009.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00044.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00019.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00007.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00050.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00020.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00001.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00046.mp4 to val set
# added lipread_mp4\PERSONAL\val\PERSONAL_00006.mp4 to val set
# finished valset

# %%
#send to dataloader
batch_size = 8
train_loader = DataLoader(trainset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(testset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(valset, batch_size=batch_size, shuffle=True)

# %%
# # # TESTING IMAGE SIZE FOR CROP
# video_path = trainset.frame_titles[2]

# # def loop_video(video_path, loop_count, duration = 0.27):
# #     # Read the video
# #     cap = cv2.VideoCapture(video_path)
# #     duration_frames = round(duration * FPS)
# #     end_frame = NUM_FRAMES -  9 # skip the last 9 frames
# #     start_frame = end_frame - duration_frames - 3  # get middle frames
# #     print(end_frame, start_frame)
# #     frames = []
# #     cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
# #     # Loop the video
# #     frame_count = 0
# #     for _ in range(loop_count):
# #         cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)  # Set frame position to the beginning
# #         while cap.isOpened():
# #             ret, frame = cap.read()
# #             if ret:
# #                 frame_count += 1
# #                 if cap.get(cv2.CAP_PROP_POS_FRAMES) == end_frame:
# #                     break
# #                 frame_cropped = frame[120:200, 70:200]
# #                 cv2.imshow('Looped Video', frame_cropped)
# #                 if cv2.waitKey(25) & 0xFF == ord('q'):
# #                     break
# #             else:
# #                 break
# #     print(frame_count)
    
# #     # Release video capture
# #     cap.release()
# #     cv2.destroyAllWindows()

# # loop_video(video_path, 10)
# print(video_path)
# def extract_frames( video_path, duration=1.16, target_resolution = (40,65), transform=None):
#     # Read the video
#     cap = cv2.VideoCapture(video_path)
#     # EXPERIEMENT WITH THIS
#     # duration_frames = int(duration * FPS)
#     # end_frame = NUM_FRAMES -  9 # skip the last 9 frames
#     # start_frame = end_frame - duration_frames # get middle frames
#     frames = []
#     # cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)

#     while cap.isOpened():
#         ret, frame = cap.read()
#         if ret:
#             # if cap.get(cv2.CAP_PROP_POS_FRAMES) == end_frame:
#             #     break
#             frame_cropped = frame[120:200, 70:200] # Crop the frame
#             #downscale the image by half to 40x65
#             # frame_cropped = cv2.resize(frame_cropped, target_resolution)
#             # frame_resized = cv2.resize(frame_cropped, target_resolution)
#             if transform:
#                 frame_tensor = transform(frame_cropped)
#             # frame_gray = cv2.cvtColor(frame_resized, cv2.COLOR_BGR2GRAY)
#             # frame_tensor = torch.from_numpy(frame_gray).to(self.device)
#             frame_tensor = frame_tensor.to('cpu').numpy()
#             frames.append(frame_tensor)
#         else:
#             break
#     #show video for 10 loops
#     loop_count = 10
#     frame_count = 0
#     cap.set(cv2.CAP_PROP_POS_FRAMES, 0)
#     for i in range(loop_count):
#         cap.set(cv2.CAP_PROP_POS_FRAMES, 0)
#         for frame in frames:
#             print(frame.shape)
#             frame_count += 1
#             cv2.imshow('Looped Video', frame[0])
#             if cv2.waitKey(25) & 0xFF == ord('q'):
#                 break
#     cap.release()
#     cv2.destroyAllWindows()
#     # return video_tensor

# extract_frames(video_path, transform=transform)

# %%
# helpers

def exists(val):
    return val is not None

# classes

class PreNorm(nn.Module):
    def __init__(self, dim, fn):
        super().__init__()
        self.fn = fn
        self.norm = nn.LayerNorm(dim)

    def forward(self, x, *args, **kwargs):
        x = self.norm(x)
        return self.fn(x, *args, **kwargs)

# time token shift

def shift(t, amt):
    if amt is 0:
        return t
    return F.pad(t, (0, 0, 0, 0, amt, -amt))

class PreTokenShift(nn.Module):
    def __init__(self, frames, fn):
        super().__init__()
        self.frames = frames
        self.fn = fn

    def forward(self, x, *args, **kwargs):
        f, dim = self.frames, x.shape[-1]
        cls_x, x = x[:, :1], x[:, 1:]
        x = rearrange(x, 'b (f n) d -> b f n d', f = f)

        # shift along time frame before and after

        dim_chunk = (dim // 3)
        chunks = x.split(dim_chunk, dim = -1)
        chunks_to_shift, rest = chunks[:3], chunks[3:]
        shifted_chunks = tuple(map(lambda args: shift(*args), zip(chunks_to_shift, (-1, 0, 1))))
        x = torch.cat((*shifted_chunks, *rest), dim = -1)

        x = rearrange(x, 'b f n d -> b (f n) d')
        x = torch.cat((cls_x, x), dim = 1)
        return self.fn(x, *args, **kwargs)

# feedforward

class GEGLU(nn.Module):
    def forward(self, x):
        x, gates = x.chunk(2, dim = -1)
        return x * F.gelu(gates)

class FeedForward(nn.Module):
    def __init__(self, dim, mult = 4, dropout = 0.):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(dim, dim * mult * 2),
            GEGLU(),
            nn.Dropout(dropout),
            nn.Linear(dim * mult, dim)
        )

    def forward(self, x):
        return self.net(x)

# attention

def attn(q, k, v, mask = None):
    sim = einsum('b i d, b j d -> b i j', q, k)

    if exists(mask):
        max_neg_value = -torch.finfo(sim.dtype).max
        sim.masked_fill_(~mask, max_neg_value)

    attn = sim.softmax(dim = -1)
    out = einsum('b i j, b j d -> b i d', attn, v)
    return out

class Attention(nn.Module):
    def __init__(
        self,
        dim,
        dim_head = 64,
        heads = 8,
        dropout = 0.
    ):
        super().__init__()
        self.heads = heads
        self.scale = dim_head ** -0.5
        inner_dim = dim_head * heads

        self.to_qkv = nn.Linear(dim, inner_dim * 3, bias = False)
        self.to_out = nn.Sequential(
            nn.Linear(inner_dim, dim),
            nn.Dropout(dropout)
        )

    def forward(self, x, einops_from, einops_to, mask = None, cls_mask = None, rot_emb = None, **einops_dims):
        h = self.heads
        q, k, v = self.to_qkv(x).chunk(3, dim = -1)
        q, k, v = map(lambda t: rearrange(t, 'b n (h d) -> (b h) n d', h = h), (q, k, v))

        q = q * self.scale

        # splice out classification token at index 1
        (cls_q, q_), (cls_k, k_), (cls_v, v_) = map(lambda t: (t[:, :1], t[:, 1:]), (q, k, v))

        # let classification token attend to key / values of all patches across time and space
        cls_out = attn(cls_q, k, v, mask = cls_mask)

        # rearrange across time or space
        q_, k_, v_ = map(lambda t: rearrange(t, f'{einops_from} -> {einops_to}', **einops_dims), (q_, k_, v_))

        # add rotary embeddings, if applicable
        if exists(rot_emb):
            q_, k_ = apply_rot_emb(q_, k_, rot_emb)

        # expand cls token keys and values across time or space and concat
        r = q_.shape[0] // cls_k.shape[0]
        cls_k, cls_v = map(lambda t: repeat(t, 'b () d -> (b r) () d', r = r), (cls_k, cls_v))

        k_ = torch.cat((cls_k, k_), dim = 1)
        v_ = torch.cat((cls_v, v_), dim = 1)

        # attention
        out = attn(q_, k_, v_, mask = mask)

        # merge back time or space
        out = rearrange(out, f'{einops_to} -> {einops_from}', **einops_dims)

        # concat back the cls token
        out = torch.cat((cls_out, out), dim = 1)

        # merge back the heads
        out = rearrange(out, '(b h) n d -> b n (h d)', h = h)

        # combine heads out
        return self.to_out(out)

# main classes

class TimeSformer(nn.Module):
    def __init__(
        self,
        *,
        dim,
        num_frames,
        num_classes,
        image_size = 96,
        patch_size = 16,
        channels = 1,
        depth = 12,
        heads = 8,
        dim_head = 64,
        attn_dropout = 0.,
        ff_dropout = 0.,
        rotary_emb = True,
        shift_tokens = False
    ):
        super().__init__()
        assert image_size % patch_size == 0, 'Image dimensions must be divisible by the patch size.'

        num_patches = (image_size // patch_size) ** 2
        num_positions = num_frames * num_patches
        patch_dim = channels * patch_size ** 2

        self.heads = heads
        self.patch_size = patch_size
        self.to_patch_embedding = nn.Linear(patch_dim, dim)
        self.cls_token = nn.Parameter(torch.randn(1, dim))

        self.use_rotary_emb = rotary_emb
        if rotary_emb:
            self.frame_rot_emb = RotaryEmbedding(dim_head)
            self.image_rot_emb = AxialRotaryEmbedding(dim_head)
        else:
            self.pos_emb = nn.Embedding(num_positions + 1, dim)


        self.layers = nn.ModuleList([])
        for _ in range(depth):
            ff = FeedForward(dim, dropout = ff_dropout)
            time_attn = Attention(dim, dim_head = dim_head, heads = heads, dropout = attn_dropout)
            spatial_attn = Attention(dim, dim_head = dim_head, heads = heads, dropout = attn_dropout)

            if shift_tokens:
                time_attn, spatial_attn, ff = map(lambda t: PreTokenShift(num_frames, t), (time_attn, spatial_attn, ff))

            time_attn, spatial_attn, ff = map(lambda t: PreNorm(dim, t), (time_attn, spatial_attn, ff))

            self.layers.append(nn.ModuleList([time_attn, spatial_attn, ff]))

        self.to_out = nn.Sequential(
            nn.LayerNorm(dim),
            nn.Linear(dim, num_classes)
        )

    def forward(self, video, mask = None):
        b, f, _, h, w, *_, device, p = *video.shape, video.device, self.patch_size
        assert h % p == 0 and w % p == 0, f'height {h} and width {w} of video must be divisible by the patch size {p}'

        # calculate num patches in height and width dimension, and number of total patches (n)

        hp, wp = (h // p), (w // p)
        n = hp * wp

        # video to patch embeddings
        video = rearrange(video, 'b f c (h p1) (w p2) -> b (f h w) (p1 p2 c)', p1 = p, p2 = p)

        tokens = self.to_patch_embedding(video)

        # add cls token

        cls_token = repeat(self.cls_token, 'n d -> b n d', b = b)
        x =  torch.cat((cls_token, tokens), dim = 1)

        # positional embedding

        frame_pos_emb = None
        image_pos_emb = None
        if not self.use_rotary_emb:
            x += self.pos_emb(torch.arange(x.shape[1], device = device))
        else:
            frame_pos_emb = self.frame_rot_emb(f, device = device)
            image_pos_emb = self.image_rot_emb(hp, wp, device = device)

        # calculate masking for uneven number of frames

        frame_mask = None
        cls_attn_mask = None
        if exists(mask):
            mask_with_cls = F.pad(mask, (1, 0), value = True)

            frame_mask = repeat(mask_with_cls, 'b f -> (b h n) () f', n = n, h = self.heads)

            cls_attn_mask = repeat(mask, 'b f -> (b h) () (f n)', n = n, h = self.heads)
            cls_attn_mask = F.pad(cls_attn_mask, (1, 0), value = True)

        # time and space attention

        for (time_attn, spatial_attn, ff) in self.layers:
            x = time_attn(x, 'b (f n) d', '(b n) f d', n = n, mask = frame_mask, cls_mask = cls_attn_mask, rot_emb = frame_pos_emb) + x
            x = spatial_attn(x, 'b (f n) d', '(b f) n d', f = f, cls_mask = cls_attn_mask, rot_emb = image_pos_emb) + x
            x = ff(x) + x

        cls_token = x[:, 0]
        return self.to_out(cls_token)
# Out:
# <>:21: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:21: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\coler\AppData\Local\Temp\ipykernel_10656\2177235015.py:21: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   if amt is 0:

# %%
def plot(loss, acc, title):
    fig, ax = plt.subplots(2)
    fig.tight_layout(pad=3.0)
    fig.suptitle(title)
    ax[0].plot(loss)
    ax[0].set_title('Training Loss')
    ax[0].set_xlabel('Epoch')
    ax[0].set_ylabel('Loss')
    ax[1].plot(acc)
    ax[1].set_title('Training Accuracy')
    ax[1].set_xlabel('Epoch')
    ax[1].set_ylabel('Accuracy')
    plt.show()

# %%
def train_and_val(model, train_loader, val_loader, optimizer, criterion, num_epochs=10):
    model.train()
    train_loss_epoch = []
    train_acc_epoch = []
    val_loss_epoch = []
    val_acc_epoch = []
    for epoch in range(num_epochs):
        train_loss = 0.0
        train_total = 0
        train_correct = 0
        val_loss = 0.0
        val_total = 0
        val_correct = 0
        for data in tqdm(train_loader):
            inputs, labels = data
            inputs.to(device)
            labels.to(device)
            optimizer.zero_grad()
            
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            _, labels_class = labels.max(dim=1)  
            _, predicted_class = outputs.max(dim=1)  
            train_correct += (predicted_class == labels_class).sum().item()
            
            train_total += labels.size(0)
            #print
            train_loss += loss.item()
        

        #save model with name based on time
        epoch_state_dict = {'model_state_dict': model.state_dict(), 'optimizer_state_dict': optimizer.state_dict()}
        torch.save(epoch_state_dict, f'transformer_{int(time.time())}.pth')
        # Validation
        model.eval()
        with torch.no_grad():
            for data in tqdm(val_loader):
                inputs, labels = data
                inputs.to(device)
                labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, labels_class = labels.max(dim=1)  
                _, predicted_class = outputs.max(dim=1)  
                val_correct += (predicted_class == labels_class).sum().item()
                val_total+= labels.size(0)
        train_loss /= len(train_loader)
        val_loss /= len(val_loader)
        print(f'Epoch {epoch + 1}\nTrain Loss: {train_loss }, Accuracy: {100 * train_correct / train_total}% \nVal Loss: {val_loss}, Accuracy: {100 * val_correct / val_total}%')
        train_loss_epoch.append(train_loss)
        train_acc_epoch.append(100 * train_correct / train_total)
        val_loss_epoch.append(val_loss)
        val_acc_epoch.append(100 * val_correct / val_total)
    plot(train_loss_epoch, train_acc_epoch, 'Training')
    plot(val_loss_epoch, val_acc_epoch, 'Validation')

    print('Finished Training')




def test(model, test_loader):
    model.eval()
    test_correct = 0
    test_total = 0
    with torch.no_grad():
        for data in test_loader:
            inputs, labels = datac
            inputs.to(device)
            labels.to(device)
            outputs = model(inputs)
            # print(labels.shape, outputs.shape)
            _, labels_class = labels.max(dim=1)  
            _, predicted_class = outputs.max(dim=1)  
            test_correct += (predicted_class == labels_class).sum().item()
            # print(predicted_class, labels_class, correct)
            # accuracy = correct_predictions / labels.size(0)  
            test_total += labels.size(0)
    print(f'Accuracy: {100 * test_correct / test_total}%')

# %%
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
#more complex
model = TimeSformer(
    dim = 512,
    num_frames = NUM_FRAMES,
    num_classes = NUM_CLASSES,
    image_size = 96,
    patch_size = 8,
    depth = 12,
    heads = 8,
    dim_head = 32,
    attn_dropout = 0.1,
    ff_dropout = 0.1,
    rotary_emb = True,
    shift_tokens = False
).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.005)
train_and_val(model, train_loader, val_loader, optimizer, criterion, num_epochs=10)
test(model, test_loader)

cnn2_state_dict = {'model_state_dict': model.state_dict(), 'optimizer_state_dict': optimizer.state_dict()}
torch.save(cnn2_state_dict, 'transformer.pth')
# Out:
#  14%|█▎        | 82/607 [10:09:59<1507:40:23, 10338.33s/it]
